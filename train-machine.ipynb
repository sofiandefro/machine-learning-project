# %%
import numpy as np 
np.random.seed(69)
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
x = heart_disease.drop("target", axis=1)
y = heart_disease["target"]
estimatorsList=[]
accuracyList=[]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
for i in range(10, 1000, 10):
    print(f"Trying model with {i} estimators...")
    clf = RandomForestClassifier(n_estimators=i).fit(x_train, y_train)
    print(f"training score: {clf.score(x_train, y_train)}, model accuracy {clf.score(x_test,y_test)*100}")
    estimatorsList.append(i)
    accuracyList.append(clf.score(x_test,y_test)*100)
    print(" ")

fig, ax = plt.subplots(figsize=(5,5))
# Out:
# Trying model with 10 estimators...
# training score: 0.9958677685950413, model accuracy 85.24590163934425
#
# Trying model with 20 estimators...
# training score: 1.0, model accuracy 83.60655737704919
#
# Trying model with 30 estimators...
# training score: 1.0, model accuracy 85.24590163934425
#
# Trying model with 40 estimators...
# training score: 1.0, model accuracy 85.24590163934425
#
# Trying model with 50 estimators...
# training score: 1.0, model accuracy 88.52459016393442
#
# Trying model with 60 estimators...
# training score: 1.0, model accuracy 86.88524590163934
#
# Trying model with 70 estimators...
# training score: 1.0, model accuracy 86.88524590163934
#
# Trying model with 80 estimators...
# training score: 1.0, model accuracy 86.88524590163934
#
# Trying model with 90 estimators...
# training score: 1.0, model accuracy 85.24590163934425
#
# Trying model with 100 estimators...
# training score: 1.0, model accuracy 86.88524590163934
#
# ...

# %%
max(accuracyList)
# Out:
# 77.04918032786885

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.plot(estimatorsList, accuracyList)

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(heart_disease["trestbps"])
# Out:
# (array([10., 42., 67., 74., 57., 27., 13.,  8.,  3.,  2.]),
#  array([ 94. , 104.6, 115.2, 125.8, 136.4, 147. , 157.6, 168.2, 178.8,
#         189.4, 200. ]),
#  <BarContainer object of 10 artists>)

# %%
max(accuracyList)
# Out:
# 88.52459016393442
